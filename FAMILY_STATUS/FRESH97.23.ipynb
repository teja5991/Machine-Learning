# %%
import numpy as np
import random
import pandas as pd

# %%
entity_id=list(range(50000))
city_type = ["A","B","C","D"]
gender = ["male","female"]
marital_status = ["married","unmarried"]
education = ["Ph.d","PG","UG","Not educated"]

#Defining the column which do not take specific values 
#creating list of random integer in the given range 
Dependents=list(range(5))
EntityIncome =list(range(10000,400000,10000))
#For EntityFamilyIncome column if the number of dependents are 0 then the Entityfamilyincome == Entiyincome this case is taken care of.
#Entityfamilyincome  column is defined later in the code

# %%
#METHOD OF GENERATING THE DATASET

#If coin flip=1(tail) if coin flip=0(head)
# Rolling the dice if head comes.
#Generating random integer in between 0 and (number of options for given feature -1) 
# meaning the number of options a feature can take
#this process is done for all the columns except for Average Expenditure per Entity per Month column
#As the ques expect us to follow other appproach for generation of that column

# %%
Dependents_vec=[]
for i in range(50000):
    coin_flip=random.randint(0,1)   #If coin flip=1(tail) if coin flip=0(head)
    if(coin_flip==0):
        dice_roll=random.randint(0,len(Dependents)-1) # Rolling the dice if head comes.
        Dependents_vec.append(Dependents[dice_roll])
    else:
        Dependents_vec.append(2)

# %%
marital_vec=[]
for i in range(50000):
    coin_flip=random.randint(0,1)     #If coin flip=1(tail) if coin flip=0(head)
    if(coin_flip==0):
        dice_roll=random.randint(0,len(marital_status)-1)# Rolling the dice if head comes.
        marital_vec.append(marital_status[dice_roll])
    else:
        marital_vec.append("married")

# %%
city_type_vec=[]
for i in range(50000):
    coin_flip=random.randint(0,1)   #If coin flip=1(tail) if coin flip=0(head)
    if(coin_flip==0):
        dice_roll=random.randint(0,len(city_type)-1)# Rolling the dice if head comes.
        city_type_vec.append(city_type[dice_roll])
    else:
        city_type_vec.append("C")

# %%
gender_vec=[]
for i in range(50000):
    coin_flip=random.randint(0,1)  #If coin flip=1(head) if coin flip=0(tail)
    if(coin_flip==0):
        dice_roll=random.randint(0,len(gender)-1)# Rolling the dice if head comes.
        gender_vec.append(gender[dice_roll])
    else:
        gender_vec.append("female")

# %%
education_vec=[]
for i in range(50000):
    coin_flip=random.randint(0,1)  #If coin flip=1(head) if coin flip=0(tail)
    if(coin_flip==0):
        dice_roll=random.randint(0,len(education)-1)# Rolling the dice if head comes.
        education_vec.append(education[dice_roll])
    else:
        education_vec.append("UG")

# %%
entity_income_vec=[]
for i in range(50000):
    coin_flip=random.randint(0,1)   #If coin flip=1(head) if coin flip=0(tail)
    if(coin_flip==0):
        dice_roll=random.randint(0,len(EntityIncome)-1)# Rolling the dice if head comes.
        entity_income_vec.append(EntityIncome[dice_roll])
    else:
        entity_income_vec.append("10000")

# %%
avg_exp_vec=[]
for i in range(50000):
        if(city_type_vec[i]== "A"):
            avg_exp_vec.append(15000)
        elif (city_type_vec[i]=="D"):
            avg_exp_vec.append(2500)
        elif (city_type_vec[i]=="C"):
            avg_exp_vec.append(5000)
        else:
            avg_exp_vec.append(10000)

# %%
entity_family_income_vec=[]

for i in range(50000):
    if(Dependents_vec[i]>0):
        entity_family_income_vec.append(random.randint(10000,100000))
    else:
        entity_family_income_vec.append(entity_income_vec[i])

# %%
total_income_vec=[]

for i in range(50000):
    j=random.randint(0,1)
    income=(int(entity_income_vec[i])+int(entity_family_income_vec[i]))
    total_income_vec.append(income)

# %%
savings_vec=[]
for i in range(50000):
    savings=(int(total_income_vec[i])-int(avg_exp_vec[i]))
    savings_vec.append(savings)

# %%
car_loan_vec=[]
for i in range(50000):
    if (int(savings_vec[i] > 50000)):
            car_loan_vec.append("Yes")
    else:       
            car_loan_vec.append("No")

# %%
house_loan_vec=[]
for i in range(50000):
    if (int(savings_vec[i] > 100000)):
            house_loan_vec.append("Yes")
    else:       
            house_loan_vec.append("No")

# %%
economic_status_vec=[]   
economic_status_label_vec=[]
for i in range(50000):
    if(savings_vec[i] >=300000):
            economic_status_vec.append("Excellent")
            economic_status_label_vec.append(0)
    elif(savings_vec[i] >200000 and savings_vec[i] < 300000 ):
            economic_status_vec.append("Good")
            economic_status_label_vec.append(1)
    elif(savings_vec[i] > 100000 and savings_vec[i] <= 200000):
            economic_status_vec.append("Moderate")
            economic_status_label_vec.append(2)
    elif(savings_vec[i] >50000 and savings_vec[i] <= 100000):
            economic_status_vec.append("Average")    
            economic_status_label_vec.append(3)
    else:
            economic_status_vec.append("Poor") 
            economic_status_label_vec.append(4)

# %%
DataSet = pd.DataFrame()
DataSet["Entity_ID"] = entity_id
DataSet["City"] = city_type_vec
DataSet["Marital Status"] = marital_vec
DataSet["Education"] = education_vec
DataSet["Gender"] =gender_vec
DataSet["Dependencies"]=Dependents_vec
DataSet["Entity's Income"]=entity_income_vec
DataSet["Entity's Family Income"]= entity_family_income_vec
DataSet["Average Expenditure per Entity per Month"]= avg_exp_vec
DataSet["Total Income of Entity's Family"] = total_income_vec
DataSet["Savings"]=savings_vec
DataSet["Car_Loan"] =car_loan_vec
DataSet["House_Loan"] =house_loan_vec
DataSet["Family Status"]= economic_status_vec
DataSet["Family_Status_Label"]=economic_status_label_vec
DataSet
# Out:
#        Entity_ID City Marital Status     Education  Gender  Dependencies  \
# 0              0    C        married          Ph.d    male             4
# 1              1    C      unmarried            UG    male             1
# 2              2    C        married            UG    male             1
# 3              3    C        married            UG  female             3
# 4              4    C        married            PG  female             2
# 5              5    B        married            UG    male             0
# 6              6    C        married            UG  female             2
# 7              7    B        married            UG    male             2
# 8              8    C        married            UG  female             2
# 9              9    C        married            UG  female             2
# 10            10    C        married            UG  female             2
# 11            11    C        married            UG    male             2
# 12            12    A      unmarried            UG    male             0
# 13            13    C        married          Ph.d  female             2
# 14            14    C        married            UG  female             4
# 15            15    C        married          Ph.d  female             2
# 16            16    D        married            UG    male             1
# 17            17    B        married            PG  female             0
# 18            18    D        married          Ph.d  female             2
# 19            19    C        married            UG  female             2
# 20            20    C        married            UG    male             3
# 21            21    D        married            UG  female             3
# 22            22    C        married          Ph.d  female             3
# 23            23    C        married            UG  female             2
# 24            24    C        married            PG  female             0
# 25            25    C        married            UG  female             0
# 26            26    C        married            UG  female             2
# 27            27    A        married  Not educated  female             4
# 28            28    C      unmarried            UG    male             4
# 29            29    C        married            UG  female             2
# ...          ...  ...            ...           ...     ...           ...
# 49970      49970    C        married            PG  female             4
# 49971      49971    C        married            UG  female             2
# 49972      49972    A      unmarried            UG  female             2
# 49973      49973    C      unmarried            PG  female             2
# 49974      49974    C        married            UG  female             1
# 49975      49975    C        married            UG  female             4
# 49976      49976    C        married            UG    male             2
# 49977      49977    C        married            PG  female             1
# 49978      49978    C        married            UG    male             2
# 49979      49979    C      unmarried            UG  female             1
# 49980      49980    B        married            UG  female             2
# 49981      49981    C        married            UG    male             2
# 49982      49982    C        married          Ph.d  female             2
# 49983      49983    B        married  Not educated  female             4
# 49984      49984    C        married            UG    male             2
# 49985      49985    C        married            UG  female             2
# 49986      49986    B      unmarried  Not educated  female             2
# 49987      49987    C      unmarried            UG  female             2
# 49988      49988    A        married            UG    male             2
# 49989      49989    C        married            UG  female             2
# 49990      49990    A      unmarried            UG  female             2
# 49991      49991    D        married            UG  female             2
# 49992      49992    C        married            UG  female             2
# 49993      49993    C      unmarried            UG  female             2
# 49994      49994    C        married            UG  female             0
# 49995      49995    A      unmarried            UG  female             2
# 49996      49996    C        married            UG  female             2
# 49997      49997    C        married  Not educated    male             2
# 49998      49998    C        married            UG    male             2
# 49999      49999    C        married            PG  female             1
#
#       Entity's Income Entity's Family Income  \
# 0               10000                  78305
# 1              120000                  32926
# 2               10000                  98065
# 3               10000                  16274
# 4              130000                  87580
# 5               10000                  10000
# 6               30000                  56015
# 7               10000                  90583
# 8               60000                  24743
# 9               60000                  80258
# 10             150000                  51754
# 11              10000                  70337
# 12             190000                 190000
# 13              10000                  50591
# 14              10000                  79770
# 15              10000                  49899
# 16              10000                  15059
# 17              30000                  30000
# 18              10000                  66244
# 19              10000                  78413
# 20              10000                  52168
# 21              10000                  33434
# 22              10000                  55172
# 23              10000                  16843
# 24             220000                 220000
# 25              10000                  10000
# 26              10000                  76040
# 27             360000                  74089
# 28              10000                  81413
# 29              10000                  94902
# ...               ...                    ...
# 49970           10000                  25947
# 49971           10000                  13177
# 49972           10000                  32365
# 49973           10000                  47916
# 49974           10000                  16636
# 49975          150000                  38988
# 49976           60000                  89608
# 49977           10000                  46722
# 49978           10000                  49314
# 49979           10000                  19489
# 49980          150000                  40773
# 49981           10000                  24601
# 49982           10000                  87635
# 49983           10000                  99038
# 49984          130000                  23866
# 49985          290000                  22239
# 49986          360000                  88768
# 49987          330000                  41159
# 49988           10000                  47203
# 49989           10000                  85811
# 49990          240000                  42089
# 49991           10000                  28187
# 49992          350000                  39366
# 49993           10000                  77395
# 49994          150000                 150000
# 49995           10000                  50517
# 49996           90000                  36453
# 49997           10000                  83484
# 49998           10000                  93269
# 49999           10000                  53266
#
#        Average Expenditure per Entity per Month  \
# 0                                          5000
# 1                                          5000
# 2                                          5000
# 3                                          5000
# 4                                          5000
# 5                                         10000
# 6                                          5000
# 7                                         10000
# 8                                          5000
# 9                                          5000
# 10                                         5000
# 11                                         5000
# 12                                        15000
# 13                                         5000
# 14                                         5000
# 15                                         5000
# 16                                         2500
# 17                                        10000
# 18                                         2500
# 19                                         5000
# 20                                         5000
# 21                                         2500
# 22                                         5000
# 23                                         5000
# 24                                         5000
# 25                                         5000
# 26                                         5000
# 27                                        15000
# 28                                         5000
# 29                                         5000
# ...                                         ...
# 49970                                      5000
# 49971                                      5000
# 49972                                     15000
# 49973                                      5000
# 49974                                      5000
# 49975                                      5000
# 49976                                      5000
# 49977                                      5000
# 49978                                      5000
# 49979                                      5000
# 49980                                     10000
# 49981                                      5000
# 49982                                      5000
# 49983                                     10000
# 49984                                      5000
# 49985                                      5000
# 49986                                     10000
# 49987                                      5000
# 49988                                     15000
# 49989                                      5000
# 49990                                     15000
# 49991                                      2500
# 49992                                      5000
# 49993                                      5000
# 49994                                      5000
# 49995                                     15000
# 49996                                      5000
# 49997                                      5000
# 49998                                      5000
# 49999                                      5000
#
#        Total Income of Entity's Family  Savings Car_Loan House_Loan  \
# 0                                88305    83305      Yes         No
# 1                               152926   147926      Yes        Yes
# 2                               108065   103065      Yes        Yes
# 3                                26274    21274       No         No
# 4                               217580   212580      Yes        Yes
# 5                                20000    10000       No         No
# 6                                86015    81015      Yes         No
# 7                               100583    90583      Yes         No
# 8                                84743    79743      Yes         No
# 9                               140258   135258      Yes        Yes
# 10                              201754   196754      Yes        Yes
# 11                               80337    75337      Yes         No
# 12                              380000   365000      Yes        Yes
# 13                               60591    55591      Yes         No
# 14                               89770    84770      Yes         No
# 15                               59899    54899      Yes         No
# 16                               25059    22559       No         No
# 17                               60000    50000       No         No
# 18                               76244    73744      Yes         No
# 19                               88413    83413      Yes         No
# 20                               62168    57168      Yes         No
# 21                               43434    40934       No         No
# 22                               65172    60172      Yes         No
# 23                               26843    21843       No         No
# 24                              440000   435000      Yes        Yes
# 25                               20000    15000       No         No
# 26                               86040    81040      Yes         No
# 27                              434089   419089      Yes        Yes
# 28                               91413    86413      Yes         No
# 29                              104902    99902      Yes         No
# ...                                ...      ...      ...        ...
# 49970                            35947    30947       No         No
# 49971                            23177    18177       No         No
# 49972                            42365    27365       No         No
# 49973                            57916    52916      Yes         No
# 49974                            26636    21636       No         No
# 49975                           188988   183988      Yes        Yes
# 49976                           149608   144608      Yes        Yes
# 49977                            56722    51722      Yes         No
# 49978                            59314    54314      Yes         No
# 49979                            29489    24489       No         No
# 49980                           190773   180773      Yes        Yes
# 49981                            34601    29601       No         No
# 49982                            97635    92635      Yes         No
# 49983                           109038    99038      Yes         No
# 49984                           153866   148866      Yes        Yes
# 49985                           312239   307239      Yes        Yes
# 49986                           448768   438768      Yes        Yes
# 49987                           371159   366159      Yes        Yes
# 49988                            57203    42203       No         No
# 49989                            95811    90811      Yes         No
# 49990                           282089   267089      Yes        Yes
# 49991                            38187    35687       No         No
# 49992                           389366   384366      Yes        Yes
# 49993                            87395    82395      Yes         No
# 49994                           300000   295000      Yes        Yes
# 49995                            60517    45517       No         No
# 49996                           126453   121453      Yes        Yes
# 49997                            93484    88484      Yes         No
# 49998                           103269    98269      Yes         No
# 49999                            63266    58266      Yes         No
#
#       Family Status  Family_Status_Label
# 0           Average                    3
# 1          Moderate                    2
# 2          Moderate                    2
# 3              Poor                    4
# 4              Good                    1
# 5              Poor                    4
# 6           Average                    3
# 7           Average                    3
# 8           Average                    3
# 9          Moderate                    2
# 10         Moderate                    2
# 11          Average                    3
# 12        Excellent                    0
# 13          Average                    3
# 14          Average                    3
# 15          Average                    3
# 16             Poor                    4
# 17             Poor                    4
# 18          Average                    3
# 19          Average                    3
# 20          Average                    3
# 21             Poor                    4
# 22          Average                    3
# 23             Poor                    4
# 24        Excellent                    0
# 25             Poor                    4
# 26          Average                    3
# 27        Excellent                    0
# 28          Average                    3
# 29          Average                    3
# ...             ...                  ...
# 49970          Poor                    4
# 49971          Poor                    4
# 49972          Poor                    4
# 49973       Average                    3
# 49974          Poor                    4
# 49975      Moderate                    2
# 49976      Moderate                    2
# 49977       Average                    3
# 49978       Average                    3
# 49979          Poor                    4
# 49980      Moderate                    2
# 49981          Poor                    4
# 49982       Average                    3
# 49983       Average                    3
# 49984      Moderate                    2
# 49985     Excellent                    0
# 49986     Excellent                    0
# 49987     Excellent                    0
# 49988          Poor                    4
# 49989       Average                    3
# 49990          Good                    1
# 49991          Poor                    4
# 49992     Excellent                    0
# 49993       Average                    3
# 49994          Good                    1
# 49995          Poor                    4
# 49996      Moderate                    2
# 49997       Average                    3
# 49998       Average                    3
# 49999       Average                    3
#
# [50000 rows x 15 columns]

# %%
temp=DataSet
# Import LabelEncoder
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X=["City","Marital Status","Education","Gender","Dependencies","Entity\'s Income","Entity\'s Family Income","Average Expenditure per Entity per Month","Total Income of Entity\'s Family","Savings","Car_Loan","House_Loan"]
Y=["Family_Status_Label"]


le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
temp['Average Expenditure per Entity per Month']=le.fit_transform(temp['Average Expenditure per Entity per Month'])
temp['Gender']=le.fit_transform(temp['Gender'])
temp['Education']=le.fit_transform(temp['Education'])
temp['Marital Status']=le.fit_transform(temp['Marital Status'])
temp['City']=le.fit_transform(temp['City'])
temp['Car_Loan'] = le.fit_transform(temp['Car_Loan'])
temp['House_Loan'] = le.fit_transform(temp['House_Loan'])

X=temp[X]
Y=temp[Y]

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)


# instantiate the model 
Log_Regression = LogisticRegression(C=10, solver='newton-cg', multi_class='multinomial')

# fit the model with data
Log_Regression.fit(X_train,Y_train)
Y_pred=Log_Regression.predict(X_test)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\utils\optimize.py:203: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   "number of iterations.", ConvergenceWarning)

# %%
print("SIZE OF TRAINING DATASET==>",X_train.size)
print("SIZE OF TESTING DATASET==>",X_test.size)
print("SHAPE OF TRAINING DATASET==>",X_train.shape)
print("SHAPE OF TESTING DATASET==>",X_test.shape)
# Out:
# SIZE OF TRAINING DATASET==> 480000
# SIZE OF TESTING DATASET==> 120000
# SHAPE OF TRAINING DATASET==> (40000, 12)
# SHAPE OF TESTING DATASET==> (10000, 12)

# %%
from sklearn import metrics

Confusion_Matrix = metrics.confusion_matrix(Y_test, Y_pred)
print(Confusion_Matrix)

FP = Confusion_Matrix .sum(axis=0) - np.diag(Confusion_Matrix )
FN = Confusion_Matrix .sum(axis=1) - np.diag(Confusion_Matrix )
TP = np.diag(Confusion_Matrix)
TN = Confusion_Matrix .sum() - (FP + FN + TP)
from sklearn.metrics import confusion_matrix
import numpy as np


Accuracy=sum(np.diag(Confusion_Matrix ))/ np.sum(Confusion_Matrix )
print("Accuracy in %= ",Accuracy*100)
# Out:
# [[1907   60    0    0    0]
#  [  84 1107   55    0    0]
#  [   0   78 1327    0    0]
#  [   0    0    0 2926    0]
#  [   0    0    0    0 2456]]
# Accuracy in %=  97.23

# %%
print("Model Evaluation Metrics")
print("Total Observations predicted",len(Y_pred))
print("True Positive=>",TP)
print("True Negative=>",TN)
print("False Positive=>",FP)
print("False Negatives=>",FN)
Accuracy = (TP+TN)/len(Y_pred)
print("Accuracy values for the 5 economic classes = ",Accuracy)
# Out:
# Model Evaluation Metrics
# Total Observations predicted 10000
# True Positive=> [1907 1107 1327 2926 2456]
# True Negative=> [7949 8616 8540 7074 7544]
# False Positive=> [ 84 138  55   0   0]
# False Negatives=> [ 60 139  78   0   0]
# Accuracy values for the 5 economic classes =  [0.9856 0.9723 0.9867 1.     1.    ]
